# %%
import numpy as np
import pandas as pd

# %%
from keras import layers
from keras.layers import Input,Dense,Embedding,Reshape,Add,Flatten,merge,Lambda,concatenate
from keras.optimizers import Adam
from keras.models import Model
from keras.utils import plot_model, np_utils
# from sklearn.preprocessing import OneHotEncoder,StandarScaler
from sklearn.metrics import accuracy_score
import random

# %%
from keras import backend as K

# %%
from keras.utils import to_categorical

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# config.py
TRAIN_FILE = r"F:\Data\recsys-data\dcn\train.csv"
TEST_FILE = r"F:\Data\recsys-data\dcn\test.csv"

SUB_DIR = "output"


NUM_SPLITS = 3
RANDOM_SEED = 2017

# types of columns of the dataset dataframe
CATEGORICAL_COLS = [
    'ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat',
    'ps_car_01_cat', 'ps_car_02_cat', 'ps_car_03_cat',
    'ps_car_04_cat', 'ps_car_05_cat', 'ps_car_06_cat',
    'ps_car_07_cat', 'ps_car_08_cat', 'ps_car_09_cat',
    'ps_car_10_cat', 'ps_car_11_cat',
]

NUMERIC_COLS = [
    # # binary
    # "ps_ind_06_bin", "ps_ind_07_bin", "ps_ind_08_bin",
    # "ps_ind_09_bin", "ps_ind_10_bin", "ps_ind_11_bin",
    # "ps_ind_12_bin", "ps_ind_13_bin", "ps_ind_16_bin",
    # "ps_ind_17_bin", "ps_ind_18_bin",
    # "ps_calc_15_bin", "ps_calc_16_bin", "ps_calc_17_bin",
    # "ps_calc_18_bin", "ps_calc_19_bin", "ps_calc_20_bin",
    # numeric
    "ps_reg_01", "ps_reg_02", "ps_reg_03",
    "ps_car_12", "ps_car_13", "ps_car_14", "ps_car_15",

    # feature engineering
    "missing_feat", "ps_car_13_x_ps_reg_03",
]

IGNORE_COLS = [
    "id", "target",
    "ps_calc_01", "ps_calc_02", "ps_calc_03", "ps_calc_04",
    "ps_calc_05", "ps_calc_06", "ps_calc_07", "ps_calc_08",
    "ps_calc_09", "ps_calc_10", "ps_calc_11", "ps_calc_12",
    "ps_calc_13", "ps_calc_14",
    "ps_calc_15_bin", "ps_calc_16_bin", "ps_calc_17_bin",
    "ps_calc_18_bin", "ps_calc_19_bin", "ps_calc_20_bin"
]

# %%
class FeatureDictionary(object):
    def __init__(self,df = None,numeric_cols = [],ignore_cols = [],cate_cols = []):
        self.df = df
        self.cate_cols = cate_cols
        self.numeric_cols = numeric_cols
        self.ignore_cols = ignore_cols
        self.gen_feat_dict()
        # feat_dict 获取cate feature每一列的字典长度。
    def gen_feat_dict(self):
#         df = self.trainfile
        self.feat_cate_len = {}
        tc = 0
        for col in self.cate_cols:
            # 获取每一列的类别
            us = self.df[col].unique()
            us_len = len(us)
            # 获取每一列的类别对应的维度
            self.feat_cate_len[col] = us_len

# %%
def load_data(df,numeric_cols = NUMERIC_COLS,cate_cols=CATEGORICAL_COLS):
    def preprocess(df):
        cols = [c for c in df.columns if c not in ['id','target']]
        df['missing_feat'] = np.sum((df[cols]==-1).values,axis=1)
        df['ps_car_13_x_ps_reg_03'] = df['ps_car_13'] * df['ps_reg_03']
        for cl in cate_cols:
            le = LabelEncoder()
            df[cl] = le.fit_transform(df[cl])
        return df
    
    Df = preprocess(df)
    cols = cate_cols + numeric_cols
    dfTrain = Df[Df['target'] != -1]
    dfTest = Df[Df['target'] == -1]
    X_train = Df[Df['target'] != -1][cols]
    y_train = to_categorical(dfTrain['target'].values)

    X_test = dfTest[cols].values
    return X_train,y_train,X_test

# %%
dfTrain = pd.read_csv(TRAIN_FILE)
dfTest = pd.read_csv(TEST_FILE)
dfTest['target'] = -1
df = pd.concat([dfTrain,dfTest])
# Out:
# D:\anaconda3\julianxu\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   after removing the cwd from sys.path.

# %%
X_train,y_train,X_test = load_data(df,numeric_cols = NUMERIC_COLS,cate_cols=CATEGORICAL_COLS)
fd = FeatureDictionary(df,numeric_cols = NUMERIC_COLS,ignore_cols=IGNORE_COLS,cate_cols=CATEGORICAL_COLS)

# %%
def embedding_layers(fd):
    # 该函数主要是定义输入和embedding输入的网络层
    embeddings_tensors = []
    continus_tensors = []
    cate_feature = fd.feat_cate_len
    numeric_feature = fd.numeric_cols
    for ec in cate_feature:
        layer_name = ec + '_inp'
        # for categorical features, embedding特征在维度保持在6×(category cardinality)**(1/4)
        embed_dim = cate_feature[ec] if int(6 * np.power(cate_feature[ec],1/4)) > cate_feature[ec] else int(6 * np.power(cate_feature[ec],1/4))
        t_inp, t_embedding = embedding_input(layer_name,cate_feature[ec],embed_dim)
        embeddings_tensors.append((t_inp,t_embedding))
        del (t_inp, t_embedding)
    for cc in numeric_feature:
        layer_name = cc +'_in'
        t_inp,t_build = continus_input(layer_name)
        continus_tensors.append((t_inp,t_build))
        del (t_inp,t_build)
    # category feature的输入 这里的输入特征顺序要与xu
    inp_layer = [et[0] for et in embeddings_tensors]
    inp_embed = [et[1] for et in embeddings_tensors]
    # numeric feature的输入
    inp_layer += [ct[0] for ct in continus_tensors]
    inp_embed += [ct[1] for ct in continus_tensors]
    
    return inp_layer,inp_embed

# %%
def embedding_input(name,input_dim,output_dim):
    inp = Input(shape = (1,),dtype = 'int64',name = name)
    embeddings = Embedding(input_dim,output_dim,input_length =1)(inp)
    return inp,embeddings
def continus_input(name):
    inp = Input(shape=(1,),dtype = 'float32',name = name)
    return inp, Reshape((1,1))(inp)

# %%
class CrossLayer(layers.Layer):
    def __init__(self,output_dim,num_layer,**kwargs):
        self.output_dim = output_dim
        self.num_layer = num_layer
        super(CrossLayer,self).__init__(**kwargs)
    
    def build(self,input_shape):
        self.input_dim = input_shape[2]
        self.W = []
        self.bias = []
        for i in range(self.num_layer):
            self.W.append(self.add_weight(shape=[1,self.input_dim],initializer = 'glorot_uniform',name='w_{}'.format(i),trainable=True))
            self.bias.append(self.add_weight(shape=[1,self.input_dim],initializer = 'zeros',name='b_{}'.format(i),trainable=True))
        self.built = True
    def call(self,input):
        for i in range(self.num_layer):
            if i==0:
#                 cross = Lambda(lambda x: Add()([K.sum(self.W[i]*K.batch_dot(K.reshape(x,(-1,self.input_dim,1)),x),axis=1,keepdims=True),self.bias[i],x]))(input)
                # 这种方法利于内存释放，先计算矩阵中简单的计算
                cross = Lambda(lambda x: K.batch_dot(K.dot(x,K.transpose(self.W[i])),x) + self.bias[i] + x)(input)
            else:
#                 cross = Lambda(lambda x: Add()([K.sum(self.W[i]*K.batch_dot(K.reshape(x,(-1,self.input_dim,1)),input),axis=1,keepdims=True),self.bias[i],input]))(cross)
                cross = Lambda(lambda x: K.batch_dot(K.dot(x,K.transpose(self.W[i])),input) + self.bias[i] + x)(cross)
        return Flatten()(cross)
        
    def compute_output_shape(self,input_shape):
        return (None,self.output_dim)

# %%
# def fit(inp_layer,inp_embed,X,y):
#     inp = concatenate(inp_embed,axis=-1)
#     #deep layer
#     for i in range(6):
#         if i ==0:
#             deep = Dense(272,activation='relu')(Flatten()(inp))
#         else:
#             deep = Dense(272,activation='relu')(deep)
#     cross = CrossLayer(output_dim = inp.shape[2],num_layer=8,name = "cross_layer")(inp)
    
#     # concat both layers 
#     output = concatenate([deep,cross],axis=-1)
#     output = Dense(y.shape[1],activation='sigmoid')(output)
#     model = Model(inp_layer,output)
#     print(model.summary())
#     model.compile(Adam(0.01),loss = 'binary_crossentropy',metrics = ['accuracy'])
#     model.fit([X[c] for c in X.columns],y,batch_size=256,epochs=10)
#     return model
# def evaluate(X,y,model):
#     y_pred = model.predict(X)
#     acc = np.sum(np.argmax(y_pred,1)==np.argamx(y,1))/y.shape[0]
#     print("Accuracy:",acc)

# %%
def DCN(inp_layer,inp_embed):
    inp = concatenate(inp_embed,axis=-1)
    #deep layer
    for i in range(6):
        if i ==0:
            deep = Dense(272,activation='relu')(Flatten()(inp))
        else:
            deep = Dense(272,activation='relu')(deep)
    cross = CrossLayer(output_dim = inp.shape[2],num_layer=8,name = "cross_layer")(inp)
        # concat both layers 
    output = concatenate([deep,cross],axis=-1)
    output = Dense(2,activation='sigmoid')(output)
    model = Model(inp_layer,output)
    return model
def fit(model,X,y):
    model = DCN(inp_layer,inp_embed)
    print(model.summary())
    model.compile(Adam(0.01),loss = 'binary_crossentropy',metrics = ['accuracy'])
    model.fit([X[c] for c in X.columns],y,batch_size=256,epochs=10)

# %%
inp_layer,inp_embed = embedding_layers(fd)
model = DCN(inp_layer,inp_embed)
fit(model,X_train,y_train)
# Out:
# Model: "model_24"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ps_ind_02_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_ind_04_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_ind_05_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_01_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_02_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_03_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_04_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_05_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_06_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_07_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_08_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_09_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_10_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_11_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_reg_01_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_reg_02_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_reg_03_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_12_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_13_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_14_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_15_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# missing_feat_in (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_13_x_ps_reg_03_in (Input (None, 1)            0
# __________________________________________________________________________________________________
# embedding_173 (Embedding)       (None, 1, 5)         25          ps_ind_02_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_174 (Embedding)       (None, 1, 3)         9           ps_ind_04_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_175 (Embedding)       (None, 1, 8)         64          ps_ind_05_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_176 (Embedding)       (None, 1, 11)        143         ps_car_01_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_177 (Embedding)       (None, 1, 2)         4           ps_car_02_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_178 (Embedding)       (None, 1, 3)         9           ps_car_03_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_179 (Embedding)       (None, 1, 10)        100         ps_car_04_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_180 (Embedding)       (None, 1, 3)         9           ps_car_05_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_181 (Embedding)       (None, 1, 12)        216         ps_car_06_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_182 (Embedding)       (None, 1, 3)         9           ps_car_07_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_183 (Embedding)       (None, 1, 2)         4           ps_car_08_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_184 (Embedding)       (None, 1, 6)         36          ps_car_09_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_185 (Embedding)       (None, 1, 3)         9           ps_car_10_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_186 (Embedding)       (None, 1, 19)        1976        ps_car_11_cat_inp[0][0]
# __________________________________________________________________________________________________
# reshape_91 (Reshape)            (None, 1, 1)         0           ps_reg_01_in[0][0]
# __________________________________________________________________________________________________
# reshape_92 (Reshape)            (None, 1, 1)         0           ps_reg_02_in[0][0]
# __________________________________________________________________________________________________
# reshape_93 (Reshape)            (None, 1, 1)         0           ps_reg_03_in[0][0]
# __________________________________________________________________________________________________
# reshape_94 (Reshape)            (None, 1, 1)         0           ps_car_12_in[0][0]
# __________________________________________________________________________________________________
# reshape_95 (Reshape)            (None, 1, 1)         0           ps_car_13_in[0][0]
# __________________________________________________________________________________________________
# reshape_96 (Reshape)            (None, 1, 1)         0           ps_car_14_in[0][0]
# __________________________________________________________________________________________________
# reshape_97 (Reshape)            (None, 1, 1)         0           ps_car_15_in[0][0]
# __________________________________________________________________________________________________
# reshape_98 (Reshape)            (None, 1, 1)         0           missing_feat_in[0][0]
# __________________________________________________________________________________________________
# reshape_99 (Reshape)            (None, 1, 1)         0           ps_car_13_x_ps_reg_03_in[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 1, 99)        0           embedding_173[0][0]
#                                                                  embedding_174[0][0]
#                                                                  embedding_175[0][0]
#                                                                  embedding_176[0][0]
#                                                                  embedding_177[0][0]
#                                                                  embedding_178[0][0]
#                                                                  embedding_179[0][0]
#                                                                  embedding_180[0][0]
#                                                                  embedding_181[0][0]
#                                                                  embedding_182[0][0]
#                                                                  embedding_183[0][0]
#                                                                  embedding_184[0][0]
#                                                                  embedding_185[0][0]
#                                                                  embedding_186[0][0]
#                                                                  reshape_91[0][0]
#                                                                  reshape_92[0][0]
#                                                                  reshape_93[0][0]
#                                                                  reshape_94[0][0]
#                                                                  reshape_95[0][0]
#                                                                  reshape_96[0][0]
#                                                                  reshape_97[0][0]
#                                                                  reshape_98[0][0]
#                                                                  reshape_99[0][0]
# __________________________________________________________________________________________________
# flatten_59 (Flatten)            (None, 99)           0           concatenate_60[0][0]
# __________________________________________________________________________________________________
# dense_207 (Dense)               (None, 272)          27200       flatten_59[0][0]
# __________________________________________________________________________________________________
# dense_208 (Dense)               (None, 272)          74256       dense_207[0][0]
# __________________________________________________________________________________________________
# dense_209 (Dense)               (None, 272)          74256       dense_208[0][0]
# __________________________________________________________________________________________________
# dense_210 (Dense)               (None, 272)          74256       dense_209[0][0]
# __________________________________________________________________________________________________
# dense_211 (Dense)               (None, 272)          74256       dense_210[0][0]
# __________________________________________________________________________________________________
# dense_212 (Dense)               (None, 272)          74256       dense_211[0][0]
# __________________________________________________________________________________________________
# cross_layer (CrossLayer)        (None, 99)           1584        concatenate_60[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 371)          0           dense_212[0][0]
#                                                                  cross_layer[0][0]
# __________________________________________________________________________________________________
# dense_213 (Dense)               (None, 2)            744         concatenate_61[0][0]
# ==================================================================================================
# Total params: 403,421
# Trainable params: 403,421
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# C:\Users\qiu\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10
# 10000/10000 [==============================] - 10s 1ms/step - loss: 0.2328 - accuracy: 0.9550
# Epoch 2/10
# 10000/10000 [==============================] - 9s 944us/step - loss: 0.1565 - accuracy: 0.9621
# Epoch 3/10
# 10000/10000 [==============================] - 10s 979us/step - loss: 0.1539 - accuracy: 0.9619
# Epoch 4/10
# 10000/10000 [==============================] - 10s 966us/step - loss: 0.1534 - accuracy: 0.9621
# Epoch 5/10
# 10000/10000 [==============================] - 9s 924us/step - loss: 0.1505 - accuracy: 0.9620
# Epoch 6/10
# 10000/10000 [==============================] - 9s 917us/step - loss: 0.1494 - accuracy: 0.9619
# Epoch 7/10
# 10000/10000 [==============================] - 9s 893us/step - loss: 0.1483 - accuracy: 0.9621
# Epoch 8/10
# 10000/10000 [==============================] - 9s 906us/step - loss: 0.1482 - accuracy: 0.9620
# Epoch 9/10
# 10000/10000 [==============================] - 9s 919us/step - loss: 0.1474 - accuracy: 0.9621
# Epoch 10/10
# 10000/10000 [==============================] - 9s 949us/step - loss: 0.1458 - accuracy: 0.9617

# %%
inp_layer,inp_embed = embedding_layers(fd)
model = DCN(inp_layer,inp_embed)
fit(model,X_train,y_train)
# Out:
# Model: "model_28"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ps_ind_02_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_ind_04_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_ind_05_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_01_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_02_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_03_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_04_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_05_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_06_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_07_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_08_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_09_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_10_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_11_cat_inp (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# ps_reg_01_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_reg_02_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_reg_03_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_12_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_13_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_14_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_15_in (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# missing_feat_in (InputLayer)    (None, 1)            0
# __________________________________________________________________________________________________
# ps_car_13_x_ps_reg_03_in (Input (None, 1)            0
# __________________________________________________________________________________________________
# embedding_201 (Embedding)       (None, 1, 5)         25          ps_ind_02_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_202 (Embedding)       (None, 1, 3)         9           ps_ind_04_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_203 (Embedding)       (None, 1, 8)         64          ps_ind_05_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_204 (Embedding)       (None, 1, 11)        143         ps_car_01_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_205 (Embedding)       (None, 1, 2)         4           ps_car_02_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_206 (Embedding)       (None, 1, 3)         9           ps_car_03_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_207 (Embedding)       (None, 1, 10)        100         ps_car_04_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_208 (Embedding)       (None, 1, 3)         9           ps_car_05_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_209 (Embedding)       (None, 1, 12)        216         ps_car_06_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_210 (Embedding)       (None, 1, 3)         9           ps_car_07_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_211 (Embedding)       (None, 1, 2)         4           ps_car_08_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_212 (Embedding)       (None, 1, 6)         36          ps_car_09_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_213 (Embedding)       (None, 1, 3)         9           ps_car_10_cat_inp[0][0]
# __________________________________________________________________________________________________
# embedding_214 (Embedding)       (None, 1, 19)        1976        ps_car_11_cat_inp[0][0]
# __________________________________________________________________________________________________
# reshape_109 (Reshape)           (None, 1, 1)         0           ps_reg_01_in[0][0]
# __________________________________________________________________________________________________
# reshape_110 (Reshape)           (None, 1, 1)         0           ps_reg_02_in[0][0]
# __________________________________________________________________________________________________
# reshape_111 (Reshape)           (None, 1, 1)         0           ps_reg_03_in[0][0]
# __________________________________________________________________________________________________
# reshape_112 (Reshape)           (None, 1, 1)         0           ps_car_12_in[0][0]
# __________________________________________________________________________________________________
# reshape_113 (Reshape)           (None, 1, 1)         0           ps_car_13_in[0][0]
# __________________________________________________________________________________________________
# reshape_114 (Reshape)           (None, 1, 1)         0           ps_car_14_in[0][0]
# __________________________________________________________________________________________________
# reshape_115 (Reshape)           (None, 1, 1)         0           ps_car_15_in[0][0]
# __________________________________________________________________________________________________
# reshape_116 (Reshape)           (None, 1, 1)         0           missing_feat_in[0][0]
# __________________________________________________________________________________________________
# reshape_117 (Reshape)           (None, 1, 1)         0           ps_car_13_x_ps_reg_03_in[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 1, 99)        0           embedding_201[0][0]
#                                                                  embedding_202[0][0]
#                                                                  embedding_203[0][0]
#                                                                  embedding_204[0][0]
#                                                                  embedding_205[0][0]
#                                                                  embedding_206[0][0]
#                                                                  embedding_207[0][0]
#                                                                  embedding_208[0][0]
#                                                                  embedding_209[0][0]
#                                                                  embedding_210[0][0]
#                                                                  embedding_211[0][0]
#                                                                  embedding_212[0][0]
#                                                                  embedding_213[0][0]
#                                                                  embedding_214[0][0]
#                                                                  reshape_109[0][0]
#                                                                  reshape_110[0][0]
#                                                                  reshape_111[0][0]
#                                                                  reshape_112[0][0]
#                                                                  reshape_113[0][0]
#                                                                  reshape_114[0][0]
#                                                                  reshape_115[0][0]
#                                                                  reshape_116[0][0]
#                                                                  reshape_117[0][0]
# __________________________________________________________________________________________________
# flatten_67 (Flatten)            (None, 99)           0           concatenate_68[0][0]
# __________________________________________________________________________________________________
# dense_235 (Dense)               (None, 272)          27200       flatten_67[0][0]
# __________________________________________________________________________________________________
# dense_236 (Dense)               (None, 272)          74256       dense_235[0][0]
# __________________________________________________________________________________________________
# dense_237 (Dense)               (None, 272)          74256       dense_236[0][0]
# __________________________________________________________________________________________________
# dense_238 (Dense)               (None, 272)          74256       dense_237[0][0]
# __________________________________________________________________________________________________
# dense_239 (Dense)               (None, 272)          74256       dense_238[0][0]
# __________________________________________________________________________________________________
# dense_240 (Dense)               (None, 272)          74256       dense_239[0][0]
# __________________________________________________________________________________________________
# cross_layer (CrossLayer)        (None, 99)           1584        concatenate_68[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 371)          0           dense_240[0][0]
#                                                                  cross_layer[0][0]
# __________________________________________________________________________________________________
# dense_241 (Dense)               (None, 2)            744         concatenate_69[0][0]
# ==================================================================================================
# Total params: 403,421
# Trainable params: 403,421
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# C:\Users\qiu\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\framework\indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/10
# 10000/10000 [==============================] - 2s 182us/step - loss: 0.1858 - accuracy: 0.9506
# Epoch 2/10
# 10000/10000 [==============================] - 1s 69us/step - loss: 0.1564 - accuracy: 0.9621
# Epoch 3/10
# 10000/10000 [==============================] - 1s 75us/step - loss: 0.1529 - accuracy: 0.9621
# Epoch 4/10
# 10000/10000 [==============================] - 1s 71us/step - loss: 0.1504 - accuracy: 0.9621
# Epoch 5/10
# 10000/10000 [==============================] - 1s 74us/step - loss: 0.1498 - accuracy: 0.9621
# Epoch 6/10
# 10000/10000 [==============================] - 1s 72us/step - loss: 0.1498 - accuracy: 0.9620
# Epoch 7/10
# 10000/10000 [==============================] - 1s 75us/step - loss: 0.1507 - accuracy: 0.9619
# Epoch 8/10
# 10000/10000 [==============================] - 1s 68us/step - loss: 0.1467 - accuracy: 0.9622
# Epoch 9/10
# 10000/10000 [==============================] - 1s 74us/step - loss: 0.1451 - accuracy: 0.9619
# Epoch 10/10
# 10000/10000 [==============================] - 1s 78us/step - loss: 0.1453 - accuracy: 0.9622 0s - loss: 0.1501
